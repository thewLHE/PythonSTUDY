# %%
#nested condition -- fold block
"""x=int(input("Enter an integer: "))
if x%2==0:
    if x%3==0:
        print("It can divisible by 2&3")
    else:
        print("Divisible by 2 but not by 3")
elif x%3==0:
    print("Divisible by 3 but not ny 2")
else:
    print("cannot divisible 2&3")"""
#compund boolean
"""x=int(input("Enter the integer x:"))
y=int(input("Enter the integer y:"))
z=int(input("Enter the integer z:"))
if x<y and x<z:
    print("x is least")
elif y<z:
    print("y is least")
else:#elif connected
    print("z is least")"""
    
    #if statement -123p
    #-  if/elif/else provides conditional execution of code blocks
"""x=int(input("Enter an integer: "))
if x>0:
    print("Hello")
    print("x>0")
elif x==0:
    print("x is 0")
else:
    print("x is negative")"""

#Test Values
    #0 (Zero), None, "", and empty objects are -->False
    #All other objects are --> True
x=-4#res -- true
if x:
    print("x is not zero")
else:
    print("Hello zero")
    #example --finding bug
#2
temp =120
if temp >100:
    print ("Really Hot")
elif temp>85:
    print("Comportable")
elif temp>60:
    print ("hot")
else: 
    print ("Cold")
# Out:
# x is not zero
# Really Hot

# %%
#Loops
    #while loop
    #-- loops iterate until a condition is met
"""lst=[1,2,3,4,5]
while lst:
    lst=lst[1:]
    print(lst)"""
    #break, continue
        #continue -- statement continues with the next iteration of the loop
        #else -- else clause belongs to the for loop, not the if statement.A loop’s else clause runs when no break occurs.

"""i=0;s=0
while True:
    if i<101:#the number change.. while loop count change either
        s+=i
        i=i+1
    else: 
        break
print(s);print("while loop finish")"""
    #example
"""stemp=input("Insert temperature");
while stemp.isdigit():
    temp=int(stemp)
    if temp >100:
        print ("Really Hot")
    elif temp>85:
        print("hot")
    elif temp>60:
        print ("Comportable")
    else: 
        print ("Cold")
    test=str(input("continue?(insert y)"))
    if test=="y"or test=="Y":
        stemp=input("Insert temperature");
        continue
    else: 
        print("program end")
        break
print("G Bye")"""
    #solv_another way
"""while True:
    stemp=input("Insert temperature");
    if stemp.isdigit():#instead " if test=="y"or test=="Y":"  
        temp=int(stemp)
    else:
        break
    if temp >100:
        print ("Really Hot")
    elif temp>85:
        print("hot")
    elif temp>60:
        print ("Comportable")
    else: 
        print ("Cold")"""
    #example
"""i=0;total=0
while i<=1000:
    total+=i#t=t+1
    i+=1
print("total : ",total,"| i value :",i)"""
    #ex -odd,even add value
"""i=0;j=2;even=0;odd=1
while even<=10 and odd <=10:
    even+=j
    evs+=even
    odd+=j
    ods+=odd
print("even : ",even,"| odd :",odd)   """
    #ex
"""j=2;even=0;odd=1
evs=0;ods=0;
inp=int(input("insert integer:("))
while inp>=even and inp>=odd:
    even+=j
    evs+=even
    odd+=j
    ods+=odd
    #print(even,"||",odd)
print("even : ",evs,"| odd :",ods)"""
    #solv -- another way
number=int(input("Enter the number of summattion:"))
i,total,evsum,oddsum=0,0,0,0
while i<=number:
    if i%2==0:
        evsum+=i
    if i%3==0:
        oddsum+=i 
    i++
    totla=evsum+oddsum
    i-+1
print("EvenSum {0} Oddsum {1}".format(i,evsum))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [88], in <cell line: 81>()
#      70 """j=2;even=0;odd=1
#      71 evs=0;ods=0;
#      72 inp=int(input("insert integer:("))
#    (...)
#      78     #print(even,"||",odd)
#      79 print("even : ",evs,"| odd :",ods)"""
#      80     #solv -- another way
# ---> 81 number=int(input("Enter the number of summattion:"))
#      82 i,total,evsum,oddsum=0,0,0,0
#      83 while i<=number:
#
# File ~/Downloads/cd/lib/python3.9/site-packages/ipykernel/kernelbase.py:1161, in Kernel.raw_input(self, prompt)
#    1157 if not self._allow_stdin:
#    1158     raise StdinNotImplementedError(
#    1159         "raw_input was called, but this frontend does not support input requests."
#    1160     )
# -> 1161 return self._input_request(
#    1162     str(prompt),
#    1163     self._parent_ident["shell"],
# ...
