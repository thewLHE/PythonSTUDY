# %%
#string formmating
    #{} syntax
    #aligment fill character
    #different bases for an integer
print('{} {} {}'.format("a","b","c"))#basic string formatting - a b c
print("{}*{}={}".format(1,2,2*1))#1*2=2
print('{0}{0}{0}{0}'.format('A'))#AAAA
print('{0}{1}{0}{1}'.format('A','B'))#ABAB
print("{2}{1}{0}".format("a","b","c"))#numbered field refer to the positiom of arguments - cba
print("{color}{n}{x}".format(n=20, x=1.5,color="blue"))#Named field refers to keyword argument - blue201.5
print('{color} {0} {x} {1}'.format(10,'foo',x=1.5,color='blue'))#blue 10 1.5 foo
from math import pi
print('{0:10} {1:10d} {c:10.2f}'.format('foo',5,c=2*pi)) #foo                 5       6.28
#positional argument   format('a','b',3,2)
#keyword argument      format(a='a',b='b',x=2)   

print('[{x:53.0f}] [{x:5.1f}] [{x:5.2f}]'.format(x=12.3456))#[                                                   12] [ 12.3] [12.35]
'{:-f}; {:-f}'.format(3.14,-3.14) #single option
#aligment 
'[{0:<10s}] [{0:10s}] [{0:^10s}]'.format('python')#'[python    ] [python    ] [  python  ]
'[{0:*<10s}] [{0:=>10s}] [{0:|^10s}]'.format("python")#'[python****] [====python] [||python||]'
'{0:x} {0:X} {0:d} {0:o} {0:b}'.format(254)#'fe FE 254 376 11111110'

#%operator formatting
s="Number are"
x=1.23
y=2000
t="%s %f and %d"%(s,x,y)
print(t)#Number are 1.230000 and 2000
z=-x ; print("%f\n%f"%(x,z))
print("%4.2f"%x)

#LIST - order sequence -[]
a=[10,20,3.0,"helo",[1,2,3]]
type(a);len(a)
b=[a,5,6] ;a+b #amke a new list
b*3
a=range(1,101); type(a) ;list(a)#일련의 규칙적인 숫자가 나오게 된다.
sum(list(a));
evenlst=sum(list(range(2,101,2)));oddlst=sum(list(range(1,101,2)))
print(evenlst+oddlst)
print(sum(list(range(0,101,3))))
    #list indexing
a=[10,11,12,13,14]
a[0];a[1]=21;#difference string
s="HELLO"
s='h'+s[1:]
print("s : %s",s)
a[-1];a[1:3];a[1:-2]#[21, 12]
a[1:2]#[21]
a[:3]#omitted indicated - [10, 21, 12]
    #list slicing
a=[10,11,12,13,14,15]
a[1:3]#[11,12]
a[1:-2]#[11, 12, 13]
a[::2]#[10, 12, 14]
a[::-1]#[15, 14, 13, 12, 11, 10]
    #modifying slices
a=[10,11,12,13,"HHHH"]
a[1:3]=[1,2]
print(a)#[10, 1, 2, 13, 'HHHH']
a[1:-1]=[]#Null list
print(a)#[10, 'HHHH']
    #operations on list
a=[1,2,3,4,5,6,7,8]
len(a)
del a[2]
print(10 in a)#FAlse
print(10 not in a)
    #lists with multiple object types
a=[10,'eleven',[12,13]]
a[1] ;a[2][0];type(a);type(a[1])
len(a[1]);
a[1].count('e')#result -> 3
a[1].upper()
a[1][3];#"v" -- for a  about string
a[2][0]=123;print(a)#[10, 'eleven', [123, 13]]
a=[10,11,12,13,14,[1,1,1,1],11]
a.append(13);#about item(any types).. [10, 11, 12, 13]
a.append([7,8,9])# [10, 11, 12, 13, [7, 789, 9]]
a.extend([1,2])#about list add..(it has difference append operation) [10, 11, 12, 13, 1, 2]
a.count(11)#insert value has been counting in list(적용한 리스트에서만 적용된다.) 
a.index(11)# value find in site number?(only first things) return
    #example
dna=['A','T','G','C','T','A','T']
dna.count('T')
dna.index('T')
    #if you wanna all of them...
firstT=dna.index('T')
sencondT=dna[firstT+1:].index('T')+firstT+1
thirdT=dna[sencondT+1:].index('T')+sencondT+1
firstT,sencondT,thirdT#(1,4,6)
    #other way..
inT=-1;
for i in range(dna.count('T')):#counting T number
    sinT=dna[inT+1:].index('T')+inT+1 #
    print(sinT)
    inT=sinT;
# Out:
# a b c
# 1*2=2
# AAAA
# ABAB
# cba
# blue201.5
# blue 10 1.5 foo
# foo                 5       6.28
# [                                                   12] [ 12.3] [12.35]
# Number are 1.230000 and 2000
# 1.230000
# -1.230000
# 1.23
# 5050
# 1683
# s : %s hELLO
# [10, 1, 2, 13, 'HHHH']
# [10, 'HHHH']
# False
# True
# [10, 'eleven', [123, 13]]
# 1
# 4
# 6
